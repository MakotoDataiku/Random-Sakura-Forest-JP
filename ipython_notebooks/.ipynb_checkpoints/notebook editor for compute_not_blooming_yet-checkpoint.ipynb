# %%
# -*- coding: utf-8 -*-
import dataiku
import pandas as pd, numpy as np
from dataiku import pandasutils as pdu

# %%
# Read recipe inputs
days_till_bloom = dataiku.Dataset("days_till_bloom")
df = days_till_bloom.get_dataframe().sort_values('date', ascending=True)

# %%
df.head()
# Out:
#                        date  days_till_bloom  year  month  day  temperature flower_status
# 0 1997-01-01 00:00:00+00:00              111  1997      1    1          2.9      note yet
# 1 1997-01-02 00:00:00+00:00              110  1997      1    2          2.2      note yet
# 2 1997-01-03 00:00:00+00:00              109  1997      1    3         -1.6      note yet
# 3 1997-01-04 00:00:00+00:00              108  1997      1    4          0.2      note yet
# 4 1997-01-05 00:00:00+00:00              107  1997      1    5         -0.4      note yet

# %%
new_df = pd.DataFrame()
for year in df.year.unique():
    sub_df = df[df['year'] == year]
    for index, row in sub_df.iterrows():
        if row['flower_status']!='bloom':
            new_df = new_df.append(row, ignore_index=False)
        else:
            break

# %%
new_df = new_df.sort_values('date', ascending=False)

# %%
new_df.head()
# Out:
#                            date   day  days_till_bloom flower_status  month  temperature    year
# 8142  2019-04-18 00:00:00+00:00  18.0              1.0      note yet    4.0         15.9  2019.0
# 8141  2019-04-17 00:00:00+00:00  17.0              2.0      note yet    4.0         14.2  2019.0
# 8140  2019-04-16 00:00:00+00:00  16.0              3.0      note yet    4.0         10.9  2019.0
# 8139  2019-04-15 00:00:00+00:00  15.0              4.0      note yet    4.0          8.8  2019.0
# 8138  2019-04-14 00:00:00+00:00  14.0              5.0      note yet    4.0         11.2  2019.0

# %%
steps = []
x = []
y = []

## Set the number of historical data points to use to predict future records
window_size = 100

## Create windows of input values
for i in range(len(df_data) - window_size - 1):
    subdf = df_data.iloc[i:i + window_size + 1]
    values = subdf['temperature'].values.tolist()[::-1]
    step = subdf['date'].values.tolist()[0]
    status = subdf['flower_status'].values.tolist()[0]

    x.append(str(values[:-1])) # append the past temperatures except for the one of the current day
    steps.append(step)
    y.append(status)

df_win = pd.DataFrame.from_dict({'date': steps, 'past_temp': x, 'flower_status': y})

# %%
# Write recipe outputs
not_blooming_yet = dataiku.Dataset("not_blooming_yet")
not_blooming_yet.write_with_schema(new_df)
