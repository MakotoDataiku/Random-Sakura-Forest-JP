# %%
# -*- coding: utf-8 -*-
import dataiku
import pandas as pd, numpy as np
from dataiku import pandasutils as pdu

# %%
# Read recipe inputs
three_cities_blooming_day = dataiku.Dataset("three_cities_blooming_day")
df = three_cities_blooming_day.get_dataframe()

# %%
df.head()
# Out:
#          年月日        開花日  年初からの日数     年  場所  状況
# 0  1991/3/30 1991-03-30       88  1991  東京  開花
# 1  1992/3/24 1992-03-24       83  1992  東京  開花
# 2  1993/3/24 1993-03-24       82  1993  東京  開花
# 3  1994/3/31 1994-03-31       89  1994  東京  開花
# 4  1995/3/31 1995-03-31       89  1995  東京  開花

# %%
df.groupby([u'場所'])

# %%
# Compute recipe outputs from inputs
# TODO: Replace this part by your actual code that computes the output, as a Pandas dataframe
# NB: DSS also supports other kinds of APIs for reading and writing data. Please see doc.

blooming_days_past_ave_df = three_cities_blooming_day_df # For this sample code, simply copy input to output


# Write recipe outputs
blooming_days_past_ave = dataiku.Dataset("blooming_days_past_ave")
blooming_days_past_ave.write_with_schema(blooming_days_past_ave_df)
