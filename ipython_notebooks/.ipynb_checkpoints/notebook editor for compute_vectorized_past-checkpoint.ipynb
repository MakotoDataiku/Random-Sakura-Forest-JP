# %%
# -*- coding: utf-8 -*-
import dataiku
import pandas as pd, numpy as np
from dataiku import pandasutils as pdu

# %%
# Read recipe inputs
days_till_blooming = dataiku.Dataset("days_till_blooming")
df = days_till_blooming.get_dataframe()

# %%
df = df.sort_values(['place', 'date_parsed'], ascending=False).reset_index(drop=True)

# %%
df.head()
# Out:
#          date               date_parsed  year  daylight  place  precip_total  temp_ave  temp_high  temp_low flower_status blooming_day blooming_day_parsed  days_till_bloom
# 0  2020/12/31 2020-12-31 00:00:00+00:00  2020       8.9  Tokyo           0.0       3.4        7.6      -0.2       not yet          NaN                 NaT              NaN
# 1  2020/12/30 2020-12-30 00:00:00+00:00  2020       1.6  Tokyo           1.5       6.9       12.3       2.7       not yet          NaN                 NaT              NaN
# 2  2020/12/29 2020-12-29 00:00:00+00:00  2020       4.5  Tokyo           0.0       8.7       13.1       4.3       not yet          NaN                 NaT              NaN
# 3  2020/12/28 2020-12-28 00:00:00+00:00  2020       4.0  Tokyo           0.0       8.5       13.5       6.2       not yet          NaN                 NaT              NaN
# ...

# %%
length = 100

# %%
var_to_vectorize = []

# %%
df['past_temperature'] = np.nan
long_vec = df['temperature'].values.tolist()

# -------------------------------------------------------------------------------- NOTEBOOK-CELL: CODE
for i in range(0, df.shape[0]):
    small_vec = str(long_vec[i+1:i+length][::-1])
    df.loc[i, "past_temperature"]=small_vec

# -------------------------------------------------------------------------------- NOTEBOOK-CELL: CODE
df

# -------------------------------------------------------------------------------- NOTEBOOK-CELL: CODE
# Write recipe outputs
not_blooming_yet = dataiku.Dataset("past_temperature")
not_blooming_yet.write_with_schema(df)

# %%
# Compute recipe outputs from inputs
# TODO: Replace this part by your actual code that computes the output, as a Pandas dataframe
# NB: DSS also supports other kinds of APIs for reading and writing data. Please see doc.

vectorized_past_df = days_till_blooming_df # For this sample code, simply copy input to output


# Write recipe outputs
vectorized_past = dataiku.Dataset("vectorized_past")
vectorized_past.write_with_schema(vectorized_past_df)
